# %%
import numpy as np

from main import (
    main,
    experiment_simple_vi,
    experiment_affine_vi,
    experiment_rock_paper_scissors,
	experiment_doubly_stochastic_game
)

# %%
exp1 = experiment_simple_vi()
# Out:
# ...
# Comparision Table: Simple VI (F(x)=x, dim=10)
# ...
# +------------------------------------+--------------+---------------+-------------+------------+
# | Algorithm                          |   Iterations |   Final Error | Converged   |   Time (s) |
# +====================================+==============+===============+=============+============+
# | Projection Method                  |           21 |   9.53674e-07 | Yes         |     0.0011 |
# +------------------------------------+--------------+---------------+-------------+------------+
# | Extragradient Method               |           50 |   7.55095e-07 | Yes         |     0.0015 |
# +------------------------------------+--------------+---------------+-------------+------------+
# | Extragradient Method With Restarts |           43 |   7.15256e-07 | Yes         |     0.0011 |
# +------------------------------------+--------------+---------------+-------------+------------+
# ...

# %%
exp2 = experiment_affine_vi()
# Out:
# ...
# Comparision Table: Affine VI (dim=10)
# ...
# +------------------------------------+--------------+---------------+-------------+------------+
# | Algorithm                          |   Iterations |   Final Error | Converged   |   Time (s) |
# +====================================+==============+===============+=============+============+
# | Projection Method                  |           47 |   8.33118e-07 | Yes         |     0.0033 |
# +------------------------------------+--------------+---------------+-------------+------------+
# | Extragradient Method               |           65 |   9.67299e-07 | Yes         |     0.0067 |
# +------------------------------------+--------------+---------------+-------------+------------+
# | Extragradient Method With Restarts |          104 |   8.2685e-07  | Yes         |     0.0027 |
# +------------------------------------+--------------+---------------+-------------+------------+
# ...

# %%
exp3 = experiment_rock_paper_scissors(max_iterations=200)
# Out:
# ...
# Comparision Table: Bilinear Saddle Point (dim=3×3)
# ...
# +----------------------+--------------+---------------+-------------+------------+
# | Algorithm            |   Iterations |   Final Error | Converged   |   Time (s) |
# +======================+==============+===============+=============+============+
# | Projection Method    |          200 |   0.600017    | No          |     0.0325 |
# +----------------------+--------------+---------------+-------------+------------+
# | Extragradient Method |          131 |   9.83118e-07 | Yes         |     0.0314 |
# +----------------------+--------------+---------------+-------------+------------+
# ...

# %%
exp4 = experiment_doubly_stochastic_game(max_iterations=200)
# Out:
# ...
# Comparision Table: Bilinear Saddle Point (dim=10×10)
# ...
# +----------------------+--------------+---------------+-------------+------------+
# | Algorithm            |   Iterations |   Final Error | Converged   |   Time (s) |
# +======================+==============+===============+=============+============+
# | Projection Method    |          200 |     0.472775  | No          |     0.0524 |
# +----------------------+--------------+---------------+-------------+------------+
# | Extragradient Method |          200 |     0.0644719 | No          |     0.0834 |
# +----------------------+--------------+---------------+-------------+------------+
# ...

# %%
main()
# Out:
# ...
# Comparision Table: Simple VI (F(x)=x, dim=10)
# ...
# +------------------------------------+--------------+---------------+-------------+------------+
# | Algorithm                          |   Iterations |   Final Error | Converged   |   Time (s) |
# +====================================+==============+===============+=============+============+
# | Projection Method                  |           21 |   9.53674e-07 | Yes         |     0.0034 |
# +------------------------------------+--------------+---------------+-------------+------------+
# | Extragradient Method               |           50 |   7.55095e-07 | Yes         |     0.0032 |
# +------------------------------------+--------------+---------------+-------------+------------+
# | Extragradient Method With Restarts |           43 |   7.15256e-07 | Yes         |     0.0012 |
# +------------------------------------+--------------+---------------+-------------+------------+
# ...
# Comparision Table: Affine VI (dim=10)
# ...
