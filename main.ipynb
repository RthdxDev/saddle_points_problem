# %%
from main import (
    experiment_simple_vi,
    experiment_linear_vi,
    experiment_bilinear_saddle_point
)

# %%
exp1 = experiment_simple_vi()
# Out:
# ...
# Comparision Table: Simple VI (F(x)=x, dim=10)
# ...
# +------------------------------------+--------------+---------------+-------------+------------+
# | Algorithm                          |   Iterations |   Final Error | Converged   |   Time (s) |
# +====================================+==============+===============+=============+============+
# | Projection Method                  |           21 |   9.53674e-07 | Yes         |     0.004  |
# +------------------------------------+--------------+---------------+-------------+------------+
# | Extragradient Method               |           50 |   7.55095e-07 | Yes         |     0.0008 |
# +------------------------------------+--------------+---------------+-------------+------------+
# | Extragradient Method With Restarts |           43 |   7.15256e-07 | Yes         |     0.0011 |
# +------------------------------------+--------------+---------------+-------------+------------+
# ...

# %%
exp2 = experiment_linear_vi()
# Out:
# ...
# Comparision Table: Linear VI (dim=10)
# ...
# +------------------------------------+--------------+---------------+-------------+------------+
# | Algorithm                          |   Iterations |   Final Error | Converged   |   Time (s) |
# +====================================+==============+===============+=============+============+
# | Projection Method                  |           47 |   9.88221e-07 | Yes         |     0.0005 |
# +------------------------------------+--------------+---------------+-------------+------------+
# | Extragradient Method               |           66 |   8.34741e-07 | Yes         |     0.001  |
# +------------------------------------+--------------+---------------+-------------+------------+
# | Extragradient Method With Restarts |          104 |   9.5009e-07  | Yes         |     0.005  |
# +------------------------------------+--------------+---------------+-------------+------------+
# ...
